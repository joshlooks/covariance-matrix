# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller, kpss
from arch.unitroot import PhillipsPerron

# %%
import numpy as np
from statsmodels.tsa.vector_ar.vecm import coint_johansen

# Example 1: Constant series
X = np.ones((100, 2))  # Two constant series

# Example 2: Perfectly collinear
Y = np.random.normal(0, 1, 100)
Z = np.vstack([Y, 2*Y]).T  # Perfectly correlated series

# Try Johansen
# coint_johansen(X, det_order=0, k_ar_diff=1)  # --> LinAlgError: Singular matrix
coint_johansen(Z, det_order=0, k_ar_diff=1)  # --> LinAlgError: Singular matrix
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /home/jlooker/Documents/covariance/scratch.ipynb Cell 2 line 1
#       <a href='vscode-notebook-cell:/home/jlooker/Documents/covariance/scratch.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> Z = np.vstack([Y, 2*Y]).T  # Perfectly correlated series
#      <a href='vscode-notebook-cell:/home/jlooker/Documents/covariance/scratch.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> # Try Johansen
#      <a href='vscode-notebook-cell:/home/jlooker/Documents/covariance/scratch.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> # coint_johansen(X, det_order=0, k_ar_diff=1)  # --> LinAlgError: Singular matrix
# ---> <a href='vscode-notebook-cell:/home/jlooker/Documents/covariance/scratch.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> coint_johansen(Z, det_order=0, k_ar_diff=1)  # --> LinAlgError: Singular matrix
#
# ...
